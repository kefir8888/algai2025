# %% [markdown]
# ### Домашнее задание 16

# %% [markdown]
# ### Задача 1.
#
# Реализуйте merge sort с делением массива на три подмассива. Изменится ли асимптотика? Сравните время работы на случайных массивах длины 10, 100, 1000, 10000.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Задача 2.
#
# Реализуйте оценку рекуррент вида $T(n) = a T(\frac{n}{b}) + n^d$ с помощью мастер-теоремы.
#
# Функция должна возвращать ответ в виде двух чисел $p$ и $q$, означающих, что $T(n) = \Theta(n^p \log^q n)$.
#
# Протестируйте свою функцию на всех случаях мастер-теоремы.

# %%
def evaluate_asymptotic_complexity(a, b, d):
    # YOUR CODE HERE
    
    
    return p, q

# %% [markdown]
# ### Задача 3.
#
# Модифицируйте код рисования дерева с занятия так, чтобы число потомков у ветви могло быть равно не только двум, но и другим целым числам.
# Вынесите отношение длины потомка к длине предка в отдельный параметр, чтобы не менять его руками.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Задача 4.
#
# Реализуйте counting sort с поддержкой отрицательных чисел. Протестируйте на массивах с большими числами (десятки миллионов). Что происходит с быстродействием и потреблением памяти в таком случае?

# %%
# YOUR CODE HERE
