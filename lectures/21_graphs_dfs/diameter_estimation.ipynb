# %%
import math

print(math.ceil(math.log(29160 / 8, 6) + 1))
# Out:
# 6

# %%
state_num = 3**8 * math.factorial(8) * math.factorial(12) * 2**12 / (3 * 2 * 2)

print(math.ceil(math.log(state_num / 18, 15) + 1))
# Out:
# 17

# %%
corner_num = 20
edge_num   = 30

state_num = 3**corner_num * math.factorial(corner_num) * math.factorial(edge_num) * 2**edge_num / (3 * 2 * 2)

print(state_num)

print(math.ceil(math.log(state_num, 12 * 2)))
# Out:
# 2.013392331070467e+68
# 50

# %%
P = 0.9
a = 0.6
k = 3

math.log(1 - P) / math.log(1 - a**k)
# Out:
# 9.462175855675222
